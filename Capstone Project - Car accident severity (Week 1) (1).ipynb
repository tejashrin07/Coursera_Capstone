# %% [markdown]
# # Introduction | Business Undertanding

# %% [markdown]
# Results of the present study showed that the severity of injuries cause by traffic accidents is in correlation with factors such as age, accident location, type of accident, time of accident, and type of moving violation.In an effort to reduce the frequency of car collisions in a community, an algorithim must be developed to predict the severity of an accident given the current weather, road and visibility conditions. When conditions are bad, this model will alert drivers to remind them to be more careful.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# we an refer variable to show severity by 'SEVERITY' because it is used measure the severity of an accident from 0 to 5 within the dataset. to identify the severity of an accident are 'WEATHER', 'ROADCONDITION' and 'LIGHTCOND','TRAFFIC'. asbelow
#
# 1: Little to no Probability (Clear Conditions)
#
# 2 : Very Low Probablility - Chance or Property Damage
#
# 3 : Low Probability - Chance of Injury
#
# 4 : Mild Probability - Chance of sevier Injury
#
# 5 : High Probability - Chance of Fatality
